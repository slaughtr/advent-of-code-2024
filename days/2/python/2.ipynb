# %% [markdown]
# - The levels are either _all increasing_ or _all decreasing_.
# - Any two adjacent levels differ by _at least one_ and _at most three_.
#
# The reports can be found safe or unsafe by checking those rules:
#
# - `7 6 4 2 1`: _Safe_ because the levels are all decreasing by 1 or 2.
# - `1 2 7 8 9`: _Unsafe_ because `2 7` is an increase of 5.
#
# Analyze the unusual data from the engineers. _How many reports are safe?_

# %%
# file is relative to where the jupyter server is started, in this case days/
with open('days/2/input.txt', 'r') as f:
    data = f.read().splitlines()

# %%
num_safe = 0

# never have I ever done so many `break` in one loop
for line in data:
    readingsStr = line.split(' ')
    readings = [ int(x) for x in readingsStr ]
    direction = ""
    for i, reading in enumerate(readings):
        if i > 0:
            diff = readings[i - 1] - reading
            # Direction must be consistently inc or dec
            if diff > 0:
                if direction == "": direction = "inc"
                if direction == "dec": break
            else:
                if direction == "": direction = "dec"
                if direction == "inc": break

            if abs(diff) < 1 or abs(diff) > 3: break
            if i == len(readings) - 1: num_safe += 1
        
print("Number that are safe: ", num_safe)
# Out:
# Number that are safe:  246

# %% [markdown]
# The Problem Dampener is a reactor-mounted module that lets the reactor safety systems _tolerate a single bad level_ in what would otherwise be a safe report. It's like the bad level never happened!
#
# Now, the same rules apply as before, except if removing a single level from an unsafe report would make it safe, the report instead counts as safe.

# %%
# How to handle removing the first item if it is bad, e.g. [5, 2, 3, 4]
def dampen(line: list[int]) -> list[int]:
    # print("Dampening list ", line)
    bad_indexes = []
    direction = ""
    for i, reading in enumerate(line):
        if i < len(line) - 1:
            diff = reading - line[i + 1]
            # Direction must be consistently inc or dec
            if diff > 0:
                if direction == "": direction = "dec"
                if direction == "inc":
                   bad_indexes.append(i + 1)
                   break
            else:
                if direction == "": direction = "inc"
                if direction == "dec":
                    bad_indexes.append(i + 1)
                    break

            if abs(diff) < 1 or abs(diff) > 3: 
                bad_indexes.append(i + 1)
                break
        
    return bad_indexes

def calculate():
    dampened_safe = 0
    og_safe = 0
    for line in data:
        readingsStr = line.split(' ')
        readings = [ int(x) for x in readingsStr ]
        readings_copy = readings.copy()
        bad_indexes = dampen(readings)
        if len(bad_indexes) == 0:
           og_safe += 1
           dampened_safe += 1
        if len(bad_indexes) == 1:
            print(f"Found bad index {bad_indexes[0]} which is value {readings[bad_indexes[0]]} from readings {readings}")
            del readings_copy[bad_indexes[0]]
            # print(f"Deleted that, new readings to try are {readings_copy}")
            second_bad_indexes = dampen(readings_copy)
            if len(second_bad_indexes) == 0: 
                dampened_safe += 1

    print("OG SAFE! ", og_safe)
    return dampened_safe

        
dampened_total = calculate()
print(dampened_total)
# Out:
# Found bad index 5 which is value 79 from readings [69, 72, 75, 78, 80, 79]
# Found bad index 7 which is value 49 from readings [40, 42, 43, 46, 47, 48, 49, 49]
# Found bad index 4 which is value 64 from readings [57, 58, 59, 60, 64]
# Found bad index 4 which is value 43 from readings [29, 32, 35, 37, 43]
# Found bad index 5 which is value 17 from readings [16, 17, 18, 19, 20, 17, 19, 20]
# Found bad index 2 which is value 43 from readings [42, 45, 43, 45, 48, 49, 46]
# Found bad index 4 which is value 63 from readings [58, 59, 62, 65, 63, 66, 66]
# Found bad index 3 which is value 31 from readings [28, 31, 34, 31, 35]
# Found bad index 3 which is value 38 from readings [37, 39, 41, 38, 40, 43, 45, 50]
# Found bad index 3 which is value 68 from readings [64, 66, 68, 68, 71]
# Found bad index 3 which is value 53 from readings [50, 51, 53, 53, 55, 53]
# Found bad index 3 which is value 48 from readings [44, 45, 48, 48, 51, 54, 55, 55]
# Found bad index 2 which is value 22 from readings [20, 22, 22, 23, 25, 29]
# Found bad index 3 which is value 41 from readings [38, 40, 41, 41, 43, 46, 49, 54]
# Found bad index 5 which is value 37 from readings [24, 27, 28, 30, 33, 37, 38, 40]
# Found bad index 4 which is value 92 from readings [82, 83, 86, 88, 92, 89]
# Found bad index 5 which is value 80 from readings [68, 69, 71, 74, 76, 80, 80]
# Found bad index 3 which is value 13 from readings [3, 6, 9, 13, 16, 20]
# Found bad index 3 which is value 71 from readings [62, 65, 67, 71, 74, 81]
# Found bad index 3 which is value 78 from readings [68, 69, 72, 78, 81]
# Found bad index 3 which is value 85 from readings [74, 77, 79, 85, 82]
# Found bad index 5 which is value 77 from readings [61, 64, 67, 69, 70, 77, 80, 80]
# Found bad index 2 which is value 53 from readings [46, 48, 53, 56, 58, 61, 65]
# Found bad index 3 which is value 77 from readings [65, 67, 70, 77, 82]
# Found bad index 2 which is value 62 from readings [61, 60, 62, 64, 65, 66, 69]
# Found bad index 2 which is value 14 from readings [13, 11, 14, 15, 18, 15]
# Found bad index 2 which is value 59 from readings [57, 56, 59, 62, 65, 66, 69, 69]
# Found bad index 2 which is value 46 from readings [45, 44, 46, 47, 48, 49, 52, 56]
# Found bad index 2 which is value 39 from readings [38, 36, 39, 42, 45, 52]
# Found bad index 2 which is value 69 from readings [69, 67, 69, 66, 69]
# Found bad index 3 which is value 87 from readings [89, 86, 84, 87, 84]
# Found bad index 3 which is value 9 from readings [10, 8, 7, 9, 11, 12, 12]
# Found bad index 3 which is value 92 from readings [97, 94, 91, 92, 94, 98]
# Found bad index 2 which is value 4 from readings [2, 1, 4, 3, 5, 6, 9, 16]
# Found bad index 2 which is value 65 from readings [63, 62, 65, 68, 68, 71, 73]
# Found bad index 2 which is value 51 from readings [54, 51, 51, 54, 55, 52]
# Found bad index 2 which is value 21 from readings [21, 20, 21, 21, 23, 26, 26]
# Found bad index 2 which is value 35 from readings [33, 32, 35, 35, 39]
# Found bad index 2 which is value 69 from readings [70, 69, 69, 72, 73, 74, 76, 82]
# Found bad index 2 which is value 4 from readings [4, 1, 4, 7, 8, 12, 15]
# Found bad index 2 which is value 8 from readings [8, 5, 8, 9, 13, 14, 16, 15]
# Found bad index 2 which is value 18 from readings [16, 15, 18, 20, 24, 25, 27, 27]
# Found bad index 2 which is value 56 from readings [54, 53, 56, 60, 62, 66]
# Found bad index 2 which is value 64 from readings [62, 60, 64, 65, 70]
# Found bad index 2 which is value 28 from readings [26, 23, 28, 30, 31]
# Found bad index 2 which is value 53 from readings [53, 51, 53, 54, 57, 62, 64, 61]
# Found bad index 2 which is value 13 from readings [9, 6, 13, 16, 18, 19, 20, 20]
# Found bad index 2 which is value 78 from readings [75, 72, 78, 80, 82, 85, 87, 91]
# Found bad index 2 which is value 10 from readings [8, 7, 10, 11, 16, 18, 25]
# Found bad index 1 which is value 84 from readings [84, 84, 86, 89, 92, 95, 96]
# Found bad index 1 which is value 36 from readings [36, 36, 39, 41, 42, 41]
# Found bad index 1 which is value 21 from readings [21, 21, 22, 24, 25, 26, 26]
# Found bad index 1 which is value 72 from readings [72, 72, 74, 77, 81]
# Found bad index 1 which is value 3 from readings [3, 3, 6, 8, 15]
# Found bad index 1 which is value 9 from readings [9, 9, 12, 11, 14]
# Found bad index 1 which is value 75 from readings [75, 75, 76, 75, 77, 75]
# Found bad index 1 which is value 7 from readings [7, 7, 8, 10, 12, 10, 10]
# Found bad index 1 which is value 52 from readings [52, 52, 51, 54, 58]
# Found bad index 1 which is value 76 from readings [76, 76, 77, 80, 79, 84]
# Found bad index 1 which is value 41 from readings [41, 41, 42, 42, 44, 45]
# Found bad index 1 which is value 85 from readings [85, 85, 87, 87, 90, 89]
# Found bad index 1 which is value 4 from readings [4, 4, 7, 9, 9, 9]
# Found bad index 1 which is value 23 from readings [23, 23, 24, 27, 30, 31, 31, 35]
# Found bad index 1 which is value 48 from readings [48, 48, 51, 51, 56]
# Found bad index 1 which is value 1 from readings [1, 1, 3, 7, 10, 13, 16, 19]
# Found bad index 1 which is value 19 from readings [19, 19, 21, 25, 26, 28, 29, 26]
# Found bad index 1 which is value 73 from readings [73, 73, 75, 76, 80, 80]
# Found bad index 1 which is value 40 from readings [40, 40, 44, 47, 51]
# Found bad index 1 which is value 74 from readings [74, 74, 78, 81, 84, 87, 93]
# Found bad index 1 which is value 9 from readings [9, 9, 11, 12, 15, 22, 25]
# Found bad index 1 which is value 1 from readings [1, 1, 3, 10, 11, 14, 16, 15]
# Found bad index 1 which is value 50 from readings [50, 50, 52, 58, 60, 60]
# Found bad index 1 which is value 59 from readings [59, 59, 60, 65, 69]
# Found bad index 1 which is value 34 from readings [34, 34, 40, 42, 47]
# Found bad index 1 which is value 34 from readings [30, 34, 36, 39, 42]
# Found bad index 1 which is value 6 from readings [2, 6, 7, 9, 12, 13, 10]
# Found bad index 1 which is value 19 from readings [15, 19, 21, 23, 24, 24]
# Found bad index 1 which is value 34 from readings [30, 34, 35, 38, 41, 44, 46, 50]
# Found bad index 1 which is value 51 from readings [47, 51, 52, 55, 60]
# Found bad index 1 which is value 94 from readings [90, 94, 92, 94, 97]
# Found bad index 1 which is value 72 from readings [68, 72, 70, 72, 75, 77, 80, 79]
# Found bad index 1 which is value 57 from readings [53, 57, 59, 60, 57, 59, 60, 60]
# Found bad index 1 which is value 92 from readings [88, 92, 95, 96, 93, 97]
# Found bad index 1 which is value 30 from readings [26, 30, 31, 29, 36]
# Found bad index 1 which is value 86 from readings [82, 86, 87, 88, 88, 90, 92, 94]
# Found bad index 1 which is value 75 from readings [71, 75, 76, 79, 79, 80, 82, 79]
# Found bad index 1 which is value 46 from readings [42, 46, 46, 49, 50, 51, 54, 54]
# Found bad index 1 which is value 18 from readings [14, 18, 18, 19, 20, 24]
# Found bad index 1 which is value 79 from readings [75, 79, 80, 80, 81, 87]
# Found bad index 1 which is value 65 from readings [61, 65, 69, 71, 74, 76]
# Found bad index 1 which is value 73 from readings [69, 73, 75, 78, 80, 84, 85, 83]
# Found bad index 1 which is value 38 from readings [34, 38, 42, 43, 46, 47, 47]
# Found bad index 1 which is value 39 from readings [35, 39, 41, 43, 47, 51]
# Found bad index 1 which is value 6 from readings [2, 6, 7, 10, 14, 20]
# Found bad index 1 which is value 21 from readings [17, 21, 24, 30, 31, 34, 36, 38]
# Found bad index 1 which is value 16 from readings [12, 16, 21, 23, 24, 23]
# Found bad index 1 which is value 91 from readings [87, 91, 93, 99, 99]
# Found bad index 1 which is value 26 from readings [22, 26, 32, 35, 36, 37, 39, 43]
# Found bad index 1 which is value 50 from readings [46, 50, 57, 59, 62, 65, 67, 73]
# Found bad index 1 which is value 52 from readings [46, 52, 54, 55, 56]
# Found bad index 1 which is value 33 from readings [27, 33, 35, 38, 40, 43, 46, 45]
# Found bad index 1 which is value 24 from readings [17, 24, 25, 27, 27]
# Found bad index 1 which is value 24 from readings [19, 24, 25, 28, 30, 32, 36]
# Found bad index 1 which is value 42 from readings [36, 42, 45, 47, 54]
# Found bad index 1 which is value 42 from readings [35, 42, 43, 44, 42, 45, 47]
# Found bad index 1 which is value 56 from readings [50, 56, 58, 55, 52]
# Found bad index 1 which is value 37 from readings [32, 37, 38, 35, 38, 38]
# Found bad index 1 which is value 54 from readings [49, 54, 57, 54, 56, 58, 60, 64]
# Found bad index 1 which is value 58 from readings [53, 58, 57, 58, 61, 64, 71]
# Found bad index 1 which is value 80 from readings [74, 80, 80, 83, 86, 87, 90, 92]
# Found bad index 1 which is value 42 from readings [36, 42, 43, 45, 45, 48, 49, 48]
# Found bad index 1 which is value 87 from readings [82, 87, 87, 89, 89]
# Found bad index 1 which is value 38 from readings [31, 38, 41, 41, 43, 45, 46, 50]
# Found bad index 1 which is value 47 from readings [40, 47, 49, 50, 50, 51, 58]
# Found bad index 1 which is value 64 from readings [59, 64, 68, 69, 71, 73, 74, 76]
# Found bad index 1 which is value 66 from readings [59, 66, 69, 73, 71]
# Found bad index 1 which is value 81 from readings [75, 81, 84, 88, 90, 92, 92]
# Found bad index 1 which is value 19 from readings [13, 19, 21, 24, 27, 31, 32, 36]
# Found bad index 1 which is value 30 from readings [23, 30, 32, 35, 39, 45]
# Found bad index 1 which is value 22 from readings [16, 22, 25, 27, 29, 31, 36, 38]
# Found bad index 1 which is value 10 from readings [3, 10, 12, 13, 19, 21, 23, 22]
# Found bad index 1 which is value 10 from readings [4, 10, 11, 14, 16, 22, 22]
# Found bad index 1 which is value 11 from readings [4, 11, 14, 16, 23, 25, 29]
# Found bad index 1 which is value 8 from readings [3, 8, 9, 10, 16, 21]
# Found bad index 5 which is value 57 from readings [64, 63, 60, 57, 55, 57]
# Found bad index 5 which is value 74 from readings [81, 80, 77, 75, 74, 74]
# Found bad index 5 which is value 24 from readings [34, 33, 31, 30, 28, 24]
# Found bad index 7 which is value 4 from readings [23, 21, 20, 19, 16, 13, 10, 4]
# Found bad index 3 which is value 52 from readings [56, 54, 51, 52, 49]
# Found bad index 5 which is value 37 from readings [44, 43, 41, 38, 35, 37, 35, 37]
# Found bad index 2 which is value 84 from readings [82, 81, 84, 81, 79, 79]
# Found bad index 3 which is value 77 from readings [77, 75, 74, 77, 74, 70]
# Found bad index 2 which is value 13 from readings [12, 11, 13, 10, 7, 2]
# Found bad index 3 which is value 28 from readings [32, 31, 28, 28, 25, 23, 20]
# Found bad index 3 which is value 2 from readings [6, 3, 2, 2, 1, 3]
# Found bad index 5 which is value 68 from readings [77, 76, 73, 71, 68, 68, 68]
# Found bad index 5 which is value 15 from readings [25, 22, 19, 17, 15, 15, 13, 9]
# Found bad index 3 which is value 84 from readings [87, 85, 84, 84, 83, 78]
# Found bad index 3 which is value 33 from readings [42, 39, 37, 33, 32, 30]
# Found bad index 5 which is value 77 from readings [88, 87, 86, 83, 81, 77, 75, 76]
# Found bad index 2 which is value 8 from readings [15, 12, 8, 6, 4, 4]
# Found bad index 3 which is value 88 from readings [96, 94, 92, 88, 86, 84, 80]
# Found bad index 4 which is value 72 from readings [84, 81, 78, 76, 72, 69, 67, 62]
# Found bad index 5 which is value 38 from readings [51, 50, 49, 46, 44, 38, 37]
# Found bad index 4 which is value 43 from readings [54, 53, 52, 49, 43, 42, 41, 43]
# Found bad index 2 which is value 92 from readings [99, 97, 92, 90, 89, 86, 86]
# Found bad index 2 which is value 88 from readings [97, 95, 88, 85, 81]
# Found bad index 3 which is value 25 from readings [35, 32, 30, 25, 22, 19, 14]
# Found bad index 2 which is value 75 from readings [73, 76, 75, 74, 73, 71, 68, 65]
# Found bad index 2 which is value 80 from readings [79, 81, 80, 79, 78, 77, 76, 78]
# Found bad index 2 which is value 6 from readings [5, 8, 6, 4, 1, 1]
# Found bad index 2 which is value 86 from readings [84, 87, 86, 83, 82, 81, 77]
# Found bad index 2 which is value 20 from readings [21, 23, 20, 18, 16, 15, 8]
# Found bad index 3 which is value 15 from readings [13, 14, 16, 15, 14, 12, 11, 9]
# Found bad index 2 which is value 29 from readings [29, 30, 29, 31, 34]
# Found bad index 3 which is value 62 from readings [58, 60, 63, 62, 59, 58, 57, 57]
# Found bad index 3 which is value 32 from readings [30, 32, 33, 32, 28]
# Found bad index 2 which is value 85 from readings [86, 87, 85, 88, 85, 84, 77]
# Found bad index 2 which is value 37 from readings [36, 37, 37, 36, 35, 32, 31, 30]
# Found bad index 2 which is value 6 from readings [4, 6, 6, 3, 6]
# Found bad index 2 which is value 29 from readings [27, 29, 29, 26, 26]
# Found bad index 2 which is value 66 from readings [65, 67, 66, 66, 64, 60]
# Found bad index 2 which is value 89 from readings [90, 91, 89, 89, 83]
# Found bad index 2 which is value 72 from readings [74, 76, 72, 71, 68, 66]
# Found bad index 2 which is value 74 from readings [74, 76, 74, 73, 69, 68, 70]
# Found bad index 2 which is value 24 from readings [23, 25, 24, 22, 18, 18]
# Found bad index 2 which is value 57 from readings [59, 61, 57, 55, 53, 51, 47]
# Found bad index 2 which is value 87 from readings [87, 88, 87, 83, 82, 81, 80, 74]
# Found bad index 2 which is value 57 from readings [55, 58, 57, 54, 51, 50, 44, 42]
# Found bad index 2 which is value 92 from readings [92, 95, 92, 91, 90, 87, 80, 83]
# Found bad index 2 which is value 64 from readings [69, 70, 64, 63, 61, 58, 58]
# Found bad index 2 which is value 36 from readings [34, 37, 36, 33, 32, 26, 24, 20]
# Found bad index 2 which is value 35 from readings [36, 37, 35, 34, 31, 24, 21, 16]
# Found bad index 1 which is value 27 from readings [27, 27, 26, 25, 24]
# Found bad index 1 which is value 41 from readings [41, 41, 38, 35, 34, 35]
# Found bad index 1 which is value 31 from readings [31, 31, 28, 27, 27]
# Found bad index 1 which is value 37 from readings [37, 37, 36, 34, 31, 28, 24]
# Found bad index 1 which is value 49 from readings [49, 49, 47, 46, 43, 41, 38, 33]
# Found bad index 1 which is value 63 from readings [63, 63, 62, 59, 62, 59, 58]
# Found bad index 1 which is value 9 from readings [9, 9, 11, 10, 13]
# Found bad index 1 which is value 23 from readings [23, 23, 21, 19, 22, 21, 21]
# Found bad index 1 which is value 37 from readings [37, 37, 40, 39, 35]
# Found bad index 1 which is value 13 from readings [13, 13, 10, 11, 5]
# Found bad index 1 which is value 78 from readings [78, 78, 78, 75, 72, 71, 70]
# Found bad index 1 which is value 73 from readings [73, 73, 73, 70, 71]
# Found bad index 1 which is value 10 from readings [10, 10, 8, 5, 5, 4, 4]
# Found bad index 1 which is value 22 from readings [22, 22, 21, 21, 20, 16]
# Found bad index 1 which is value 96 from readings [96, 96, 96, 95, 89]
# Found bad index 1 which is value 41 from readings [41, 41, 40, 36, 33, 32, 29, 28]
# Found bad index 1 which is value 57 from readings [57, 57, 53, 51, 54]
# Found bad index 1 which is value 58 from readings [58, 58, 57, 56, 55, 51, 51]
# Found bad index 1 which is value 46 from readings [46, 46, 42, 39, 35]
# Found bad index 1 which is value 21 from readings [21, 21, 18, 14, 12, 11, 5]
# Found bad index 1 which is value 40 from readings [40, 40, 38, 36, 29, 27, 25]
# Found bad index 1 which is value 97 from readings [97, 97, 94, 89, 91]
# Found bad index 1 which is value 36 from readings [36, 36, 34, 29, 27, 25, 22, 22]
# Found bad index 1 which is value 87 from readings [87, 87, 84, 79, 75]
# Found bad index 1 which is value 35 from readings [35, 35, 32, 26, 24, 21, 16]
# Found bad index 1 which is value 48 from readings [52, 48, 45, 42, 40, 37]
# Found bad index 1 which is value 45 from readings [49, 45, 42, 40, 42]
# Found bad index 1 which is value 91 from readings [95, 91, 88, 86, 86]
# Found bad index 1 which is value 84 from readings [88, 84, 82, 81, 80, 78, 75, 71]
# Found bad index 1 which is value 79 from readings [83, 79, 78, 76, 70]
# Found bad index 1 which is value 13 from readings [17, 13, 11, 10, 9, 10, 7]
# Found bad index 1 which is value 41 from readings [45, 41, 43, 41, 42]
# Found bad index 1 which is value 93 from readings [97, 93, 90, 89, 92, 89, 89]
# Found bad index 1 which is value 13 from readings [17, 13, 15, 14, 12, 8]
# Found bad index 1 which is value 32 from readings [36, 32, 29, 27, 29, 27, 22]
# Found bad index 1 which is value 46 from readings [50, 46, 45, 44, 41, 41, 40, 39]
# Found bad index 1 which is value 89 from readings [93, 89, 87, 84, 84, 87]
# Found bad index 1 which is value 19 from readings [23, 19, 17, 16, 16, 16]
# Found bad index 1 which is value 25 from readings [29, 25, 24, 22, 22, 20, 18, 14]
# Found bad index 1 which is value 10 from readings [14, 10, 9, 9, 8, 3]
# Found bad index 1 which is value 16 from readings [20, 16, 13, 9, 6]
# Found bad index 1 which is value 18 from readings [22, 18, 16, 13, 9, 11]
# Found bad index 1 which is value 69 from readings [73, 69, 66, 62, 62]
# Found bad index 1 which is value 12 from readings [16, 12, 8, 5, 1]
# Found bad index 1 which is value 54 from readings [58, 54, 50, 47, 45, 40]
# Found bad index 1 which is value 42 from readings [46, 42, 40, 33, 30]
# Found bad index 1 which is value 61 from readings [65, 61, 54, 51, 54]
# Found bad index 1 which is value 21 from readings [25, 21, 20, 19, 17, 15, 9, 9]
# Found bad index 1 which is value 34 from readings [38, 34, 31, 25, 24, 20]
# Found bad index 1 which is value 67 from readings [71, 67, 66, 64, 58, 56, 51]
# Found bad index 1 which is value 73 from readings [78, 73, 70, 69, 68, 65]
# Found bad index 1 which is value 26 from readings [32, 26, 24, 22, 21, 19, 22]
# Found bad index 1 which is value 86 from readings [92, 86, 84, 83, 81, 78, 78]
# Found bad index 1 which is value 62 from readings [67, 62, 59, 56, 53, 49]
# Found bad index 1 which is value 58 from readings [64, 58, 56, 55, 54, 52, 51, 46]
# Found bad index 1 which is value 76 from readings [82, 76, 74, 72, 74, 71, 69, 66]
# Found bad index 1 which is value 32 from readings [37, 32, 30, 32, 29, 32]
# Found bad index 1 which is value 58 from readings [65, 58, 57, 59, 56, 55, 52, 52]
# Found bad index 1 which is value 87 from readings [94, 87, 84, 87, 83]
# Found bad index 1 which is value 47 from readings [54, 47, 49, 48, 45, 39]
# Found bad index 1 which is value 68 from readings [74, 68, 65, 62, 62, 60, 59]
# Found bad index 1 which is value 47 from readings [53, 47, 44, 43, 43, 46]
# Found bad index 1 which is value 89 from readings [96, 89, 86, 86, 85, 85]
# Found bad index 1 which is value 55 from readings [62, 55, 53, 52, 52, 51, 47]
# Found bad index 1 which is value 28 from readings [34, 28, 28, 25, 20]
# Found bad index 1 which is value 20 from readings [25, 20, 16, 13, 11, 9]
# Found bad index 1 which is value 52 from readings [58, 52, 49, 45, 42, 39, 40]
# Found bad index 1 which is value 49 from readings [56, 49, 45, 43, 40, 37, 37]
# Found bad index 1 which is value 26 from readings [32, 26, 22, 20, 16]
# Found bad index 1 which is value 88 from readings [94, 88, 84, 82, 75]
# Found bad index 1 which is value 59 from readings [65, 59, 58, 52, 50, 49, 47]
# Found bad index 1 which is value 61 from readings [68, 61, 55, 53, 55]
# Found bad index 1 which is value 47 from readings [53, 47, 45, 40, 40]
# Found bad index 1 which is value 66 from readings [73, 66, 61, 59, 57, 53]
# Found bad index 1 which is value 60 from readings [66, 60, 57, 56, 51, 46]
# Found bad index 7 which is value 42 from readings [32, 34, 37, 38, 40, 43, 44, 42]
# Found bad index 6 which is value 20 from readings [9, 11, 14, 17, 19, 20, 20]
# Found bad index 7 which is value 34 from readings [18, 19, 21, 24, 26, 27, 30, 34]
# Found bad index 7 which is value 85 from readings [68, 71, 73, 75, 77, 79, 80, 85]
# Found bad index 4 which is value 80 from readings [75, 76, 79, 81, 80, 81, 84]
# Found bad index 3 which is value 41 from readings [40, 43, 44, 41, 40]
# Found bad index 4 which is value 22 from readings [17, 20, 23, 25, 22, 23, 23]
# Found bad index 3 which is value 93 from readings [89, 91, 94, 93, 97]
# Found bad index 3 which is value 25 from readings [20, 23, 26, 25, 28, 30, 37]
# Found bad index 2 which is value 30 from readings [28, 30, 30, 31, 32, 33]
# Found bad index 2 which is value 25 from readings [23, 25, 25, 26, 25]
# Found bad index 5 which is value 78 from readings [70, 73, 75, 76, 78, 78, 81, 81]
# Found bad index 2 which is value 19 from readings [18, 19, 19, 21, 22, 23, 27]
# Found bad index 5 which is value 86 from readings [78, 80, 82, 83, 86, 86, 91]
# Found bad index 5 which is value 18 from readings [7, 10, 11, 12, 14, 18, 19]
# Found bad index 2 which is value 97 from readings [92, 93, 97, 98, 95]
# Found bad index 2 which is value 40 from readings [33, 36, 40, 41, 41]
# Found bad index 3 which is value 83 from readings [77, 78, 79, 83, 87]
# Found bad index 2 which is value 54 from readings [49, 50, 54, 57, 60, 63, 65, 72]
# Found bad index 5 which is value 90 from readings [75, 78, 79, 80, 83, 90, 92]
# Found bad index 3 which is value 92 from readings [82, 84, 85, 92, 94, 91]
# Found bad index 4 which is value 61 from readings [47, 50, 53, 55, 61, 63, 63]
# Found bad index 4 which is value 56 from readings [47, 48, 49, 50, 56, 59, 63]
# Found bad index 5 which is value 36 from readings [23, 24, 26, 28, 31, 36, 41]
# Found bad index 2 which is value 27 from readings [28, 26, 27, 28, 31]
# Found bad index 2 which is value 5 from readings [5, 2, 5, 6, 3]
# Found bad index 2 which is value 83 from readings [82, 81, 83, 85, 87, 88, 91, 91]
# Found bad index 2 which is value 29 from readings [30, 28, 29, 31, 32, 36]
# Found bad index 2 which is value 38 from readings [39, 37, 38, 40, 42, 45, 51]
# Found bad index 3 which is value 16 from readings [16, 14, 13, 16, 19]
# Found bad index 2 which is value 38 from readings [40, 37, 38, 40, 39, 41, 39]
# Found bad index 2 which is value 62 from readings [62, 59, 62, 64, 62, 62]
# Found bad index 2 which is value 71 from readings [72, 70, 71, 68, 71, 74, 76, 80]
# Found bad index 3 which is value 28 from readings [27, 26, 25, 28, 29, 31, 37]
# Found bad index 2 which is value 31 from readings [30, 28, 31, 34, 34, 35]
# Found bad index 2 which is value 47 from readings [50, 47, 47, 48, 50, 52, 51]
# Found bad index 2 which is value 41 from readings [41, 40, 41, 44, 44, 46, 47, 47]
# Found bad index 2 which is value 48 from readings [48, 47, 48, 51, 52, 52, 56]
# Found bad index 2 which is value 5 from readings [6, 3, 5, 7, 10, 10, 15]
# Found bad index 2 which is value 4 from readings [3, 2, 4, 5, 6, 8, 12, 15]
# Found bad index 2 which is value 86 from readings [88, 85, 86, 87, 91, 94, 91]
# Found bad index 2 which is value 59 from readings [59, 56, 59, 63, 65, 65]
# Found bad index 2 which is value 45 from readings [44, 43, 45, 49, 53]
# Found bad index 2 which is value 49 from readings [47, 46, 49, 53, 55, 56, 62]
# Found bad index 2 which is value 36 from readings [32, 30, 36, 38, 39, 41]
# Found bad index 2 which is value 27 from readings [27, 24, 27, 30, 31, 38, 39, 38]
# Found bad index 2 which is value 68 from readings [64, 61, 68, 70, 70]
# Found bad index 2 which is value 55 from readings [54, 52, 55, 60, 61, 63, 67]
# Found bad index 2 which is value 27 from readings [23, 20, 27, 30, 37]
# Found bad index 1 which is value 21 from readings [21, 21, 23, 26, 27, 28, 30, 33]
# Found bad index 1 which is value 22 from readings [22, 22, 23, 24, 23]
# Found bad index 1 which is value 36 from readings [36, 36, 39, 42, 44, 44]
# Found bad index 1 which is value 48 from readings [48, 48, 51, 53, 57]
# Found bad index 1 which is value 19 from readings [19, 19, 21, 24, 27, 29, 30, 35]
# Found bad index 1 which is value 35 from readings [35, 35, 33, 34, 35, 38, 39]
# Found bad index 1 which is value 74 from readings [74, 74, 73, 75, 72]
# Found bad index 1 which is value 75 from readings [75, 75, 77, 74, 75, 76, 76]
# Found bad index 1 which is value 24 from readings [24, 24, 27, 28, 25, 28, 30, 34]
# Found bad index 1 which is value 67 from readings [67, 67, 65, 67, 70, 72, 79]
# Found bad index 1 which is value 44 from readings [44, 44, 45, 46, 49, 49, 51, 52]
# Found bad index 1 which is value 69 from readings [69, 69, 72, 72, 69]
# Found bad index 1 which is value 28 from readings [28, 28, 28, 31, 34, 36, 36]
# Found bad index 1 which is value 53 from readings [53, 53, 53, 55, 56, 60]
# Found bad index 1 which is value 51 from readings [51, 51, 51, 52, 54, 59]
# Found bad index 1 which is value 82 from readings [82, 82, 84, 88, 89]
# Found bad index 1 which is value 66 from readings [66, 66, 67, 70, 71, 75, 73]
# Found bad index 1 which is value 82 from readings [82, 82, 85, 89, 91, 91]
# Found bad index 1 which is value 32 from readings [32, 32, 35, 37, 40, 44, 48]
# Found bad index 1 which is value 27 from readings [27, 27, 30, 33, 37, 42]
# Found bad index 1 which is value 77 from readings [77, 77, 80, 86, 89, 92, 95]
# Found bad index 1 which is value 65 from readings [65, 65, 68, 70, 77, 79, 77]
# Found bad index 1 which is value 86 from readings [86, 86, 87, 89, 91, 97, 99, 99]
# Found bad index 1 which is value 31 from readings [31, 31, 36, 39, 41, 45]
# Found bad index 1 which is value 6 from readings [6, 6, 9, 14, 17, 18, 25]
# Found bad index 1 which is value 31 from readings [27, 31, 32, 34, 36]
# Found bad index 1 which is value 59 from readings [55, 59, 62, 65, 67, 70, 71, 69]
# Found bad index 1 which is value 8 from readings [4, 8, 11, 14, 15, 16, 16]
# Found bad index 1 which is value 7 from readings [3, 7, 8, 11, 13, 17]
# Found bad index 1 which is value 77 from readings [73, 77, 80, 82, 85, 87, 89, 96]
# Found bad index 1 which is value 89 from readings [85, 89, 91, 94, 93, 94, 96, 97]
# Found bad index 1 which is value 12 from readings [8, 12, 13, 12, 15, 18, 17]
# Found bad index 1 which is value 55 from readings [51, 55, 52, 53, 53]
# Found bad index 1 which is value 25 from readings [21, 25, 28, 30, 29, 31, 34, 38]
# Found bad index 1 which is value 52 from readings [48, 52, 55, 52, 57]
# Found bad index 1 which is value 5 from readings [1, 5, 6, 6, 8, 9]
# Found bad index 1 which is value 41 from readings [37, 41, 44, 45, 47, 47, 45]
# Found bad index 1 which is value 48 from readings [44, 48, 50, 50, 50]
# Found bad index 1 which is value 76 from readings [72, 76, 76, 77, 78, 79, 83]
# Found bad index 1 which is value 58 from readings [54, 58, 59, 60, 63, 64, 64, 70]
# Found bad index 1 which is value 22 from readings [18, 22, 24, 27, 31, 32]
# Found bad index 1 which is value 37 from readings [33, 37, 40, 44, 45, 43]
# Found bad index 1 which is value 17 from readings [13, 17, 21, 22, 24, 26, 26]
# Found bad index 1 which is value 28 from readings [24, 28, 31, 33, 37, 39, 42, 46]
# Found bad index 1 which is value 23 from readings [19, 23, 24, 28, 30, 35]
# Found bad index 1 which is value 43 from readings [39, 43, 45, 52, 53]
# Found bad index 1 which is value 61 from readings [57, 61, 62, 68, 70, 68]
# Found bad index 1 which is value 44 from readings [40, 44, 51, 54, 54]
# Found bad index 1 which is value 64 from readings [60, 64, 69, 70, 71, 75]
# Found bad index 1 which is value 44 from readings [40, 44, 46, 53, 56, 59, 66]
# Found bad index 1 which is value 32 from readings [25, 32, 35, 37, 40, 43]
# Found bad index 1 which is value 68 from readings [63, 68, 70, 72, 73, 74, 73]
# Found bad index 1 which is value 41 from readings [34, 41, 42, 43, 43]
# Found bad index 1 which is value 6 from readings [1, 6, 7, 10, 11, 15]
# Found bad index 1 which is value 28 from readings [23, 28, 31, 34, 39]
# Found bad index 1 which is value 96 from readings [91, 96, 95, 96, 98]
# Found bad index 1 which is value 88 from readings [81, 88, 85, 88, 86]
# Found bad index 1 which is value 60 from readings [54, 60, 62, 59, 60, 60]
# Found bad index 1 which is value 37 from readings [30, 37, 36, 39, 43]
# Found bad index 1 which is value 51 from readings [44, 51, 53, 51, 57]
# Found bad index 1 which is value 30 from readings [25, 30, 31, 33, 33, 36, 37, 39]
# Found bad index 1 which is value 92 from readings [85, 92, 94, 94, 93]
# Found bad index 1 which is value 8 from readings [2, 8, 9, 11, 11, 11]
# Found bad index 1 which is value 46 from readings [41, 46, 49, 49, 51, 54, 58]
# Found bad index 1 which is value 63 from readings [58, 63, 65, 67, 67, 68, 69, 74]
# Found bad index 1 which is value 50 from readings [45, 50, 52, 56, 57, 60, 63]
# Found bad index 1 which is value 34 from readings [29, 34, 38, 40, 37]
# Found bad index 1 which is value 74 from readings [67, 74, 76, 80, 80]
# Found bad index 1 which is value 64 from readings [57, 64, 68, 70, 71, 75]
# Found bad index 1 which is value 13 from readings [6, 13, 16, 19, 23, 26, 29, 36]
# Found bad index 1 which is value 31 from readings [26, 31, 32, 37, 39, 41, 44, 47]
# Found bad index 1 which is value 72 from readings [67, 72, 77, 80, 78]
# Found bad index 1 which is value 81 from readings [76, 81, 86, 88, 90, 90]
# Found bad index 1 which is value 72 from readings [65, 72, 75, 78, 80, 85, 86, 90]
# Found bad index 1 which is value 38 from readings [32, 38, 43, 44, 45, 47, 52]
# Found bad index 7 which is value 53 from readings [61, 60, 58, 57, 56, 54, 51, 53]
# Found bad index 4 which is value 86 from readings [92, 90, 89, 86, 86]
# Found bad index 4 which is value 61 from readings [70, 68, 67, 65, 61]
# Found bad index 7 which is value 68 from readings [87, 84, 81, 80, 79, 78, 75, 68]
# Found bad index 3 which is value 40 from readings [41, 38, 37, 40, 38, 35, 34]
# Found bad index 3 which is value 96 from readings [99, 96, 95, 96, 98]
# Found bad index 3 which is value 52 from readings [53, 51, 50, 52, 50, 50]
# Found bad index 4 which is value 14 from readings [17, 15, 14, 13, 14, 10]
# Found bad index 2 which is value 17 from readings [16, 15, 17, 14, 13, 6]
# Found bad index 2 which is value 30 from readings [31, 30, 30, 27, 24, 23]
# Found bad index 3 which is value 39 from readings [43, 42, 39, 39, 38, 41]
# Found bad index 6 which is value 46 from readings [58, 55, 52, 49, 47, 46, 46, 46]
# Found bad index 3 which is value 58 from readings [61, 59, 58, 58, 55, 51]
# Found bad index 2 which is value 55 from readings [58, 55, 55, 54, 52, 49, 46, 39]
# Found bad index 2 which is value 38 from readings [43, 42, 38, 37, 35]
# Found bad index 2 which is value 89 from readings [96, 93, 89, 88, 87, 90]
# Found bad index 5 which is value 70 from readings [80, 79, 76, 75, 74, 70, 70]
# Found bad index 5 which is value 42 from readings [53, 50, 49, 47, 46, 42, 38]
# Found bad index 2 which is value 31 from readings [38, 35, 31, 29, 28, 22]
# Found bad index 4 which is value 74 from readings [87, 84, 81, 79, 74, 73, 71]
# Found bad index 4 which is value 12 from readings [23, 22, 20, 19, 12, 11, 8, 10]
# Found bad index 3 which is value 9 from readings [20, 17, 16, 9, 9]
# Found bad index 3 which is value 10 from readings [20, 18, 16, 10, 7, 3]
# Found bad index 3 which is value 11 from readings [21, 19, 17, 11, 8, 7, 2]
# Found bad index 2 which is value 62 from readings [64, 65, 62, 61, 60, 59, 57]
# Found bad index 2 which is value 17 from readings [17, 18, 17, 14, 12, 15]
# Found bad index 2 which is value 63 from readings [61, 64, 63, 60, 59, 57, 57]
# Found bad index 2 which is value 88 from readings [88, 91, 88, 86, 83, 79]
# Found bad index 2 which is value 97 from readings [97, 99, 97, 94, 88]
# Found bad index 3 which is value 69 from readings [69, 70, 72, 69, 66]
# Found bad index 2 which is value 23 from readings [23, 24, 23, 24, 25]
# Found bad index 2 which is value 44 from readings [43, 46, 44, 42, 44, 43, 41, 41]
# Found bad index 2 which is value 19 from readings [19, 20, 19, 21, 19, 15]
# Found bad index 3 which is value 63 from readings [62, 63, 64, 63, 61, 59, 57, 51]
# Found bad index 2 which is value 89 from readings [90, 91, 89, 86, 86, 83, 81, 78]
# Found bad index 2 which is value 72 from readings [73, 74, 72, 71, 71, 68, 66, 69]
# Found bad index 2 which is value 38 from readings [37, 40, 38, 36, 36, 33, 31, 31]
# Found bad index 2 which is value 38 from readings [35, 38, 38, 35, 31]
# Found bad index 2 which is value 77 from readings [76, 77, 77, 74, 68]
# Found bad index 2 which is value 75 from readings [76, 78, 75, 73, 69, 66]
# Found bad index 2 which is value 64 from readings [67, 68, 64, 61, 58, 55, 53, 55]
# Found bad index 2 which is value 51 from readings [53, 55, 51, 49, 46, 44, 44]
# Found bad index 2 which is value 44 from readings [47, 48, 44, 43, 39]
# Found bad index 2 which is value 89 from readings [89, 92, 89, 86, 82, 76]
# Found bad index 2 which is value 27 from readings [26, 29, 27, 21, 20]
# Found bad index 2 which is value 74 from readings [78, 80, 74, 73, 70, 69, 70]
# Found bad index 2 which is value 72 from readings [75, 78, 72, 70, 70]
# Found bad index 2 which is value 15 from readings [16, 18, 15, 9, 5]
# Found bad index 2 which is value 70 from readings [73, 76, 70, 67, 65, 63, 58]
# Found bad index 1 which is value 37 from readings [37, 37, 35, 32, 29, 26, 23]
# Found bad index 1 which is value 41 from readings [41, 41, 39, 36, 33, 32, 30, 33]
# Found bad index 1 which is value 75 from readings [75, 75, 72, 70, 67, 66, 65, 65]
# Found bad index 1 which is value 26 from readings [26, 26, 24, 23, 22, 21, 17]
# Found bad index 1 which is value 98 from readings [98, 98, 97, 94, 93, 91, 88, 82]
# Found bad index 1 which is value 14 from readings [14, 14, 15, 13, 10, 8, 5, 3]
# Found bad index 1 which is value 33 from readings [33, 33, 31, 29, 26, 28, 29]
# Found bad index 1 which is value 31 from readings [31, 31, 29, 26, 28, 28]
# Found bad index 1 which is value 91 from readings [91, 91, 88, 86, 87, 85, 81]
# Found bad index 1 which is value 72 from readings [72, 72, 70, 73, 70, 67, 64, 57]
# Found bad index 1 which is value 22 from readings [22, 22, 22, 20, 19, 17]
# Found bad index 1 which is value 74 from readings [74, 74, 74, 71, 69, 66, 63, 64]
# Found bad index 1 which is value 25 from readings [25, 25, 22, 22, 22]
# Found bad index 1 which is value 33 from readings [33, 33, 32, 30, 28, 28, 24]
# Found bad index 1 which is value 84 from readings [84, 84, 81, 78, 78, 76, 71]
# Found bad index 1 which is value 19 from readings [19, 19, 15, 12, 9, 8, 7]
# Found bad index 1 which is value 74 from readings [74, 74, 71, 70, 66, 63, 65]
# Found bad index 1 which is value 46 from readings [46, 46, 45, 41, 41]
# Found bad index 1 which is value 38 from readings [38, 38, 34, 33, 29]
# Found bad index 1 which is value 44 from readings [44, 44, 43, 39, 32]
# Found bad index 1 which is value 17 from readings [17, 17, 10, 8, 5]
# Found bad index 1 which is value 89 from readings [89, 89, 87, 85, 84, 79, 78, 80]
# Found bad index 1 which is value 21 from readings [21, 21, 18, 17, 12, 12]
# Found bad index 1 which is value 66 from readings [66, 66, 65, 62, 60, 54, 50]
# Found bad index 1 which is value 81 from readings [81, 81, 78, 76, 69, 66, 63, 57]
# Found bad index 1 which is value 36 from readings [40, 36, 34, 33, 30, 29]
# Found bad index 1 which is value 26 from readings [30, 26, 25, 23, 22, 20, 21]
# Found bad index 1 which is value 20 from readings [24, 20, 17, 14, 13, 11, 10, 10]
# Found bad index 1 which is value 80 from readings [84, 80, 77, 75, 72, 71, 67]
# Found bad index 1 which is value 60 from readings [64, 60, 58, 55, 53, 48]
# Found bad index 1 which is value 84 from readings [88, 84, 83, 85, 82]
# Found bad index 1 which is value 29 from readings [33, 29, 32, 30, 31]
# Found bad index 1 which is value 69 from readings [73, 69, 67, 70, 70]
# Found bad index 1 which is value 91 from readings [95, 91, 88, 87, 85, 84, 85, 81]
# Found bad index 1 which is value 30 from readings [34, 30, 29, 26, 27, 22]
# Found bad index 1 which is value 57 from readings [61, 57, 57, 55, 52, 49, 47]
# Found bad index 1 which is value 44 from readings [48, 44, 43, 43, 46]
# Found bad index 1 which is value 71 from readings [75, 71, 70, 68, 68, 65, 64, 64]
# Found bad index 1 which is value 42 from readings [46, 42, 42, 40, 36]
# Found bad index 1 which is value 75 from readings [79, 75, 72, 72, 69, 64]
# Found bad index 1 which is value 92 from readings [96, 92, 91, 87, 85, 83, 82, 80]
# Found bad index 1 which is value 76 from readings [80, 76, 75, 71, 69, 67, 70]
# Found bad index 1 which is value 57 from readings [61, 57, 53, 51, 51]
# Found bad index 1 which is value 17 from readings [21, 17, 15, 13, 11, 7, 3]
# Found bad index 1 which is value 22 from readings [26, 22, 19, 15, 12, 6]
# Found bad index 1 which is value 69 from readings [73, 69, 67, 60, 58, 57, 56]
# Found bad index 1 which is value 53 from readings [57, 53, 47, 46, 48]
# Found bad index 1 which is value 61 from readings [65, 61, 59, 56, 51, 48, 48]
# Found bad index 1 which is value 31 from readings [35, 31, 28, 22, 21, 17]
# Found bad index 1 which is value 45 from readings [49, 45, 43, 36, 34, 33, 30, 24]
# Found bad index 1 which is value 41 from readings [46, 41, 40, 37, 34, 32]
# Found bad index 1 which is value 73 from readings [79, 73, 70, 67, 65, 63, 60, 63]
# Found bad index 1 which is value 32 from readings [37, 32, 31, 30, 30]
# Found bad index 1 which is value 59 from readings [66, 59, 58, 56, 55, 54, 50]
# Found bad index 1 which is value 36 from readings [42, 36, 34, 32, 26]
# Found bad index 1 which is value 67 from readings [74, 67, 66, 68, 65, 64, 62]
# Found bad index 1 which is value 27 from readings [34, 27, 24, 22, 25, 23, 21, 23]
# Found bad index 1 which is value 19 from readings [24, 19, 16, 17, 15, 15]
# Found bad index 1 which is value 33 from readings [40, 33, 32, 30, 33, 31, 30, 26]
# Found bad index 1 which is value 66 from readings [73, 66, 65, 66, 60]
# Found bad index 1 which is value 16 from readings [23, 16, 14, 14, 12, 9, 6]
# Found bad index 1 which is value 69 from readings [74, 69, 67, 64, 64, 65]
# Found bad index 1 which is value 40 from readings [47, 40, 37, 35, 32, 29, 29, 29]
# Found bad index 1 which is value 31 from readings [37, 31, 28, 25, 22, 20, 20, 16]
# Found bad index 1 which is value 53 from readings [60, 53, 51, 49, 48, 48, 46, 39]
# Found bad index 1 which is value 70 from readings [76, 70, 66, 63, 60]
# Found bad index 1 which is value 52 from readings [59, 52, 48, 47, 50]
# Found bad index 1 which is value 43 from readings [49, 43, 42, 38, 38]
# Found bad index 1 which is value 79 from readings [84, 79, 75, 73, 72, 71, 67]
# Found bad index 1 which is value 69 from readings [75, 69, 68, 64, 62, 60, 55]
# Found bad index 1 which is value 66 from readings [71, 66, 60, 57, 56]
# Found bad index 1 which is value 64 from readings [70, 64, 57, 54, 53, 51, 48, 51]
# Found bad index 1 which is value 83 from readings [89, 83, 77, 75, 72, 69, 69]
# Found bad index 1 which is value 45 from readings [50, 45, 44, 42, 40, 38, 31, 27]
# Found bad index 1 which is value 33 from readings [40, 33, 27, 26, 23, 20, 13]
# Found bad index 6 which is value 23 from readings [12, 13, 16, 19, 22, 24, 23]
# Found bad index 7 which is value 56 from readings [45, 48, 51, 52, 53, 54, 56, 56]
# Found bad index 5 which is value 42 from readings [30, 31, 33, 35, 38, 42]
# Found bad index 4 which is value 93 from readings [81, 82, 84, 87, 93]
# Found bad index 4 which is value 13 from readings [10, 13, 14, 15, 13, 16]
# Found bad index 6 which is value 51 from readings [46, 49, 51, 52, 53, 54, 51, 49]
# Found bad index 3 which is value 16 from readings [13, 14, 17, 16, 16]
# Found bad index 3 which is value 39 from readings [36, 39, 42, 39, 42, 45, 47, 51]
# Found bad index 3 which is value 12 from readings [11, 13, 15, 12, 19]
# Found bad index 2 which is value 55 from readings [54, 55, 55, 57, 60]
# Found bad index 2 which is value 33 from readings [30, 33, 33, 36, 39, 37]
# Found bad index 3 which is value 45 from readings [42, 44, 45, 45, 46, 48, 48]
# Found bad index 2 which is value 35 from readings [34, 35, 35, 36, 39, 43]
# Found bad index 3 which is value 37 from readings [32, 34, 37, 37, 40, 43, 48]
# Found bad index 2 which is value 29 from readings [22, 25, 29, 32, 33]
# Found bad index 4 which is value 15 from readings [6, 9, 10, 11, 15, 14]
# Found bad index 2 which is value 82 from readings [77, 78, 82, 84, 87, 87]
# Found bad index 2 which is value 30 from readings [24, 26, 30, 33, 34, 35, 37, 41]
# Found bad index 4 which is value 56 from readings [45, 48, 51, 52, 56, 63]
# Found bad index 4 which is value 28 from readings [18, 21, 22, 23, 28, 29, 31, 33]
# Found bad index 4 which is value 22 from readings [9, 10, 13, 16, 22, 21]
# Found bad index 2 which is value 38 from readings [31, 32, 38, 41, 43, 43]
# Found bad index 3 which is value 84 from readings [72, 74, 77, 84, 85, 88, 89, 93]
# Found bad index 3 which is value 49 from readings [37, 39, 42, 49, 51, 52, 59]
# Found bad index 2 which is value 73 from readings [73, 72, 73, 76, 77, 79]
# Found bad index 2 which is value 6 from readings [6, 3, 6, 7, 10, 11, 9]
# Found bad index 2 which is value 69 from readings [67, 66, 69, 72, 74, 76, 78, 78]
# Found bad index 2 which is value 6 from readings [8, 5, 6, 9, 10, 11, 12, 16]
# Found bad index 2 which is value 59 from readings [60, 57, 59, 60, 63, 64, 70]
# Found bad index 3 which is value 33 from readings [35, 32, 30, 33, 36, 39, 41, 42]
# Found bad index 3 which is value 28 from readings [29, 28, 26, 28, 31, 32, 29]
# Found bad index 3 which is value 91 from readings [94, 92, 90, 91, 92, 92]
# Found bad index 3 which is value 20 from readings [23, 20, 18, 20, 22, 23, 27]
# Found bad index 2 which is value 11 from readings [10, 9, 11, 8, 14]
# Found bad index 2 which is value 38 from readings [38, 35, 38, 38, 41, 42]
# Found bad index 2 which is value 23 from readings [23, 20, 23, 23, 26, 29, 26]
# Found bad index 2 which is value 58 from readings [61, 58, 58, 61, 63, 63]
# Found bad index 2 which is value 62 from readings [64, 61, 62, 65, 65, 68, 72]
# Found bad index 2 which is value 6 from readings [7, 5, 6, 6, 13]
# Found bad index 2 which is value 13 from readings [12, 9, 13, 15, 18, 19, 22, 23]
# Found bad index 2 which is value 17 from readings [16, 14, 17, 21, 24, 23]
# Found bad index 2 which is value 72 from readings [71, 68, 72, 73, 75, 75]
# Found bad index 2 which is value 14 from readings [12, 11, 14, 16, 20, 22, 23, 27]
# Found bad index 2 which is value 11 from readings [10, 8, 11, 15, 16, 22]
# Found bad index 2 which is value 55 from readings [54, 53, 55, 58, 63, 64]
# Found bad index 2 which is value 90 from readings [89, 87, 90, 95, 92]
# Found bad index 2 which is value 17 from readings [17, 15, 17, 19, 21, 22, 29, 29]
# Found bad index 2 which is value 50 from readings [46, 43, 50, 51, 55]
# Found bad index 2 which is value 48 from readings [48, 45, 48, 49, 54, 59]
# Found bad index 1 which is value 82 from readings [82, 82, 85, 88, 89, 91]
# Found bad index 1 which is value 11 from readings [11, 11, 12, 13, 14, 17, 14]
# Found bad index 1 which is value 77 from readings [77, 77, 78, 79, 80, 81, 84, 84]
# Found bad index 1 which is value 74 from readings [74, 74, 77, 79, 80, 81, 85]
# Found bad index 1 which is value 22 from readings [22, 22, 23, 24, 31]
# Found bad index 1 which is value 82 from readings [82, 82, 81, 83, 85, 88, 89, 92]
# Found bad index 1 which is value 26 from readings [26, 26, 29, 30, 27, 30, 29]
# Found bad index 1 which is value 56 from readings [56, 56, 57, 60, 63, 65, 62, 62]
# Found bad index 1 which is value 72 from readings [72, 72, 71, 74, 78]
# Found bad index 1 which is value 5 from readings [5, 5, 8, 6, 11]
# Found bad index 1 which is value 74 from readings [74, 74, 77, 78, 78, 80, 83]
# Found bad index 1 which is value 27 from readings [27, 27, 30, 30, 33, 31]
# Found bad index 1 which is value 16 from readings [16, 16, 16, 19, 20, 22, 22]
# Found bad index 1 which is value 77 from readings [77, 77, 79, 81, 81, 85]
# Found bad index 1 which is value 37 from readings [37, 37, 39, 40, 41, 41, 43, 48]
# Found bad index 1 which is value 67 from readings [67, 67, 68, 69, 73, 74, 76, 79]
# Found bad index 1 which is value 3 from readings [3, 3, 6, 8, 12, 15, 14]
# Found bad index 1 which is value 83 from readings [83, 83, 87, 88, 89, 92, 92]
# Found bad index 1 which is value 22 from readings [22, 22, 26, 29, 30, 31, 34, 38]
# Found bad index 1 which is value 2 from readings [2, 2, 5, 8, 10, 13, 17, 23]
# Found bad index 1 which is value 68 from readings [68, 68, 71, 78, 81]
# Found bad index 1 which is value 15 from readings [15, 15, 17, 22, 24, 21]
# Found bad index 1 which is value 10 from readings [10, 10, 13, 16, 23, 23]
# Found bad index 1 which is value 16 from readings [16, 16, 17, 18, 24, 27, 31]
# Found bad index 1 which is value 25 from readings [25, 25, 27, 29, 32, 39, 46]
# Found bad index 1 which is value 27 from readings [23, 27, 28, 31, 33, 36, 37]
# Found bad index 1 which is value 87 from readings [83, 87, 89, 91, 88]
# Found bad index 1 which is value 48 from readings [44, 48, 49, 50, 53, 53]
# Found bad index 1 which is value 50 from readings [46, 50, 52, 54, 57, 61]
# Found bad index 1 which is value 13 from readings [9, 13, 16, 17, 19, 22, 29]
# Found bad index 1 which is value 35 from readings [31, 35, 36, 33, 35]
# Found bad index 1 which is value 85 from readings [81, 85, 84, 86, 85]
# Found bad index 1 which is value 7 from readings [3, 7, 9, 12, 15, 18, 15, 15]
# Found bad index 1 which is value 54 from readings [50, 54, 53, 55, 59]
# Found bad index 1 which is value 50 from readings [46, 50, 51, 54, 52, 58]
# Found bad index 1 which is value 62 from readings [58, 62, 63, 66, 66, 67, 70]
# Found bad index 1 which is value 39 from readings [35, 39, 39, 41, 43, 41]
# Found bad index 1 which is value 33 from readings [29, 33, 36, 37, 37, 37]
# Found bad index 1 which is value 17 from readings [13, 17, 17, 20, 24]
# Found bad index 1 which is value 75 from readings [71, 75, 75, 76, 79, 81, 84, 89]
# Found bad index 1 which is value 25 from readings [21, 25, 29, 31, 32, 33, 35]
# Found bad index 1 which is value 37 from readings [33, 37, 40, 44, 46, 48, 47]
# Found bad index 1 which is value 9 from readings [5, 9, 12, 13, 15, 19, 19]
# Found bad index 1 which is value 27 from readings [23, 27, 30, 34, 37, 38, 42]
# Found bad index 1 which is value 55 from readings [51, 55, 56, 60, 63, 64, 70]
# Found bad index 1 which is value 54 from readings [50, 54, 57, 60, 62, 63, 68, 69]
# Found bad index 1 which is value 28 from readings [24, 28, 31, 32, 33, 36, 43, 40]
# Found bad index 1 which is value 28 from readings [24, 28, 29, 30, 36, 37, 38, 38]
# Found bad index 1 which is value 56 from readings [52, 56, 61, 63, 66, 70]
# Found bad index 1 which is value 19 from readings [15, 19, 25, 27, 29, 34]
# Found bad index 1 which is value 33 from readings [26, 33, 36, 38, 41]
# Found bad index 1 which is value 30 from readings [23, 30, 33, 34, 32]
# Found bad index 1 which is value 70 from readings [65, 70, 72, 74, 75, 75]
# Found bad index 1 which is value 18 from readings [13, 18, 20, 22, 26]
# Found bad index 1 which is value 50 from readings [43, 50, 53, 55, 58, 59, 66]
# Found bad index 1 which is value 17 from readings [12, 17, 19, 18, 21, 24]
# Found bad index 1 which is value 33 from readings [27, 33, 36, 37, 38, 37, 40, 38]
# Found bad index 1 which is value 81 from readings [74, 81, 82, 84, 85, 84, 86, 86]
# Found bad index 1 which is value 26 from readings [19, 26, 23, 25, 26, 28, 32]
# Found bad index 1 which is value 83 from readings [77, 83, 84, 81, 88]
# Found bad index 1 which is value 55 from readings [48, 55, 58, 61, 64, 64, 65]
# Found bad index 1 which is value 45 from readings [40, 45, 47, 47, 48, 49, 47]
# Found bad index 1 which is value 63 from readings [58, 63, 65, 67, 70, 71, 71, 71]
# Found bad index 1 which is value 35 from readings [30, 35, 36, 39, 39, 42, 46]
# Found bad index 1 which is value 81 from readings [74, 81, 83, 86, 86, 92]
# Found bad index 1 which is value 72 from readings [67, 72, 74, 76, 79, 83, 84, 85]
# Found bad index 1 which is value 54 from readings [49, 54, 56, 60, 61, 62, 61]
# Found bad index 1 which is value 67 from readings [62, 67, 71, 73, 74, 74]
# Found bad index 1 which is value 43 from readings [38, 43, 47, 48, 51, 54, 57, 61]
# Found bad index 1 which is value 26 from readings [19, 26, 27, 30, 34, 40]
# Found bad index 1 which is value 46 from readings [41, 46, 52, 54, 55, 56]
# Found bad index 1 which is value 42 from readings [36, 42, 44, 50, 51, 50]
# Found bad index 1 which is value 17 from readings [11, 17, 20, 21, 26, 29, 30, 30]
# Found bad index 1 which is value 30 from readings [24, 30, 33, 39, 41, 42, 46]
# Found bad index 1 which is value 8 from readings [3, 8, 11, 17, 19, 25]
# Found bad index 6 which is value 79 from readings [85, 84, 81, 80, 79, 76, 79]
# Found bad index 4 which is value 10 from readings [17, 14, 12, 10, 10]
# Found bad index 4 which is value 19 from readings [30, 27, 25, 23, 19]
# Found bad index 5 which is value 7 from readings [23, 20, 18, 15, 14, 7]
# Found bad index 4 which is value 34 from readings [38, 36, 35, 33, 34, 32]
# Found bad index 3 which is value 57 from readings [59, 58, 56, 57, 56, 54, 56]
# Found bad index 2 which is value 46 from readings [45, 44, 46, 44, 41, 41]
# Found bad index 4 which is value 18 from readings [24, 21, 19, 16, 18, 16, 13, 9]
# Found bad index 5 which is value 74 from readings [79, 77, 75, 73, 72, 74, 72, 66]
# Found bad index 3 which is value 39 from readings [43, 42, 39, 39, 37]
# Found bad index 3 which is value 28 from readings [33, 30, 28, 28, 25, 24, 22, 24]
# Found bad index 4 which is value 10 from readings [15, 13, 11, 10, 10, 9, 6, 6]
# Found bad index 3 which is value 91 from readings [94, 93, 91, 91, 88, 84]
# Found bad index 2 which is value 50 from readings [52, 50, 50, 47, 42]
# Found bad index 3 which is value 50 from readings [59, 57, 54, 50, 47, 46, 44, 42]
# Found bad index 3 which is value 8 from readings [16, 14, 12, 8, 6, 8]
# Found bad index 2 which is value 84 from readings [91, 88, 84, 82, 82]
# Found bad index 3 which is value 26 from readings [34, 31, 30, 26, 24, 23, 19]
# Found bad index 5 which is value 74 from readings [85, 84, 81, 79, 78, 74, 68]
# Found bad index 5 which is value 82 from readings [94, 93, 91, 90, 87, 82, 79, 78]
# Found bad index 2 which is value 18 from readings [28, 25, 18, 16, 17]
# Found bad index 2 which is value 69 from readings [78, 75, 69, 68, 67, 64, 61, 61]
# Found bad index 2 which is value 28 from readings [37, 34, 28, 26, 22]
# Found bad index 3 which is value 90 from readings [98, 96, 95, 90, 83]
# Found bad index 2 which is value 50 from readings [48, 51, 50, 47, 46]
# Found bad index 2 which is value 37 from readings [38, 39, 37, 36, 38]
# Found bad index 2 which is value 49 from readings [49, 51, 49, 47, 45, 44, 44]
# Found bad index 2 which is value 63 from readings [61, 64, 63, 60, 58, 54]
# Found bad index 2 which is value 18 from readings [18, 19, 18, 16, 11]
# Found bad index 2 which is value 88 from readings [88, 89, 88, 90, 87, 85, 84, 82]
# Found bad index 3 which is value 10 from readings [6, 8, 11, 10, 11]
# Found bad index 2 which is value 90 from readings [91, 93, 90, 87, 84, 87, 85, 85]
# Found bad index 2 which is value 78 from readings [77, 80, 78, 81, 80, 78, 74]
# Found bad index 3 which is value 22 from readings [21, 24, 25, 22, 17]
# Found bad index 2 which is value 85 from readings [86, 88, 85, 82, 82, 80]
# Found bad index 2 which is value 51 from readings [51, 53, 51, 51, 50, 48, 49]
# Found bad index 2 which is value 55 from readings [53, 55, 55, 52, 50, 49, 49]
# Found bad index 2 which is value 29 from readings [27, 30, 29, 29, 25]
# Found bad index 2 which is value 52 from readings [54, 55, 52, 50, 50, 47, 41]
# Found bad index 2 which is value 60 from readings [59, 61, 60, 56, 53, 50, 48]
# Found bad index 2 which is value 81 from readings [82, 85, 81, 79, 78, 75, 77]
# Found bad index 2 which is value 59 from readings [59, 61, 59, 55, 53, 53]
# Found bad index 2 which is value 26 from readings [27, 29, 26, 22, 20, 19, 18, 14]
# Found bad index 2 which is value 49 from readings [51, 52, 49, 45, 38]
# Found bad index 2 which is value 38 from readings [39, 40, 38, 37, 36, 35, 29, 26]
# Found bad index 2 which is value 65 from readings [65, 66, 65, 59, 57, 56, 54, 56]
# Found bad index 2 which is value 92 from readings [93, 94, 92, 87, 86, 86]
# Found bad index 2 which is value 40 from readings [39, 41, 40, 37, 31, 28, 24]
# Found bad index 2 which is value 39 from readings [43, 46, 39, 36, 30]
# Found bad index 1 which is value 46 from readings [46, 46, 44, 43, 40]
# Found bad index 1 which is value 42 from readings [42, 42, 41, 38, 36, 34, 37]
# Found bad index 1 which is value 45 from readings [45, 45, 44, 42, 39, 37, 34, 34]
# Found bad index 1 which is value 81 from readings [81, 81, 80, 78, 75, 71]
# Found bad index 1 which is value 29 from readings [29, 29, 28, 26, 25, 22, 16]
# Found bad index 1 which is value 83 from readings [83, 83, 82, 85, 84]
# Found bad index 1 which is value 70 from readings [70, 70, 67, 66, 69, 67, 70]
# Found bad index 1 which is value 31 from readings [31, 31, 29, 32, 32]
# Found bad index 1 which is value 47 from readings [47, 47, 44, 46, 42]
# Found bad index 1 which is value 11 from readings [11, 11, 12, 11, 10, 3]
# Found bad index 1 which is value 81 from readings [81, 81, 79, 77, 77, 76]
# Found bad index 1 which is value 79 from readings [79, 79, 79, 76, 78]
# Found bad index 1 which is value 28 from readings [28, 28, 25, 25, 25]
# Found bad index 1 which is value 66 from readings [66, 66, 63, 60, 60, 58, 55, 51]
# Found bad index 1 which is value 18 from readings [18, 18, 18, 15, 14, 12, 5]
# Found bad index 1 which is value 35 from readings [35, 35, 33, 31, 30, 26, 24]
# Found bad index 1 which is value 7 from readings [7, 7, 3, 2, 5]
# Found bad index 1 which is value 76 from readings [76, 76, 74, 73, 69, 67, 66, 66]
# Found bad index 1 which is value 30 from readings [30, 30, 28, 24, 23, 22, 18]
# Found bad index 1 which is value 92 from readings [92, 92, 89, 85, 84, 82, 75]
# Found bad index 1 which is value 42 from readings [42, 42, 41, 38, 36, 30, 29, 26]
# Found bad index 1 which is value 74 from readings [74, 74, 73, 70, 68, 61, 58, 60]
# Found bad index 1 which is value 74 from readings [74, 74, 72, 67, 67]
# Found bad index 1 which is value 76 from readings [76, 76, 69, 66, 63, 59]
# Found bad index 1 which is value 66 from readings [66, 66, 63, 62, 61, 55, 54, 49]
# Found bad index 1 which is value 93 from readings [97, 93, 91, 88, 85, 82, 79, 76]
# Found bad index 1 which is value 54 from readings [58, 54, 52, 49, 46, 43, 46]
# Found bad index 1 which is value 88 from readings [92, 88, 85, 82, 80, 79, 79]
# Found bad index 1 which is value 82 from readings [86, 82, 80, 79, 76, 74, 70]
# Found bad index 1 which is value 28 from readings [32, 28, 25, 22, 20, 13]
# Found bad index 1 which is value 64 from readings [68, 64, 61, 59, 57, 54, 55, 53]
# Found bad index 1 which is value 68 from readings [72, 68, 70, 67, 64, 67]
# Found bad index 1 which is value 92 from readings [96, 92, 95, 94, 92, 92]
# Found bad index 1 which is value 54 from readings [58, 54, 52, 54, 51, 47]
# Found bad index 1 which is value 35 from readings [39, 35, 33, 32, 34, 32, 26]
# Found bad index 1 which is value 83 from readings [87, 83, 81, 79, 76, 76, 73, 70]
# Found bad index 1 which is value 50 from readings [54, 50, 49, 49, 50]
# Found bad index 1 which is value 74 from readings [78, 74, 74, 73, 73]
# Found bad index 1 which is value 49 from readings [53, 49, 49, 47, 45, 41]
# Found bad index 1 which is value 60 from readings [64, 60, 60, 59, 57, 55, 52, 46]
# Found bad index 1 which is value 60 from readings [64, 60, 59, 55, 54]
# Found bad index 1 which is value 9 from readings [13, 9, 5, 4, 7]
# Found bad index 1 which is value 19 from readings [23, 19, 17, 15, 11, 11]
# Found bad index 1 which is value 82 from readings [86, 82, 80, 79, 75, 72, 69, 65]
# Found bad index 1 which is value 84 from readings [88, 84, 80, 77, 76, 70]
# Found bad index 1 which is value 85 from readings [89, 85, 83, 82, 75, 73, 70]
# Found bad index 1 which is value 82 from readings [86, 82, 77, 76, 74, 72, 69, 70]
# Found bad index 1 which is value 28 from readings [32, 28, 25, 23, 22, 21, 14, 14]
# Found bad index 1 which is value 73 from readings [77, 73, 70, 68, 61, 59, 57, 53]
# Found bad index 1 which is value 54 from readings [58, 54, 48, 47, 46, 45, 39]
# Found bad index 1 which is value 11 from readings [16, 11, 9, 7, 4, 1]
# Found bad index 1 which is value 17 from readings [24, 17, 14, 13, 14]
# Found bad index 1 which is value 65 from readings [71, 65, 63, 61, 58, 56, 53, 53]
# Found bad index 1 which is value 80 from readings [85, 80, 79, 77, 76, 75, 71]
# Found bad index 1 which is value 77 from readings [83, 77, 76, 74, 73, 70, 67, 60]
# Found bad index 1 which is value 83 from readings [88, 83, 80, 81, 79, 77, 75]
# Found bad index 1 which is value 67 from readings [72, 67, 69, 67, 65, 63, 61, 64]
# Found bad index 1 which is value 12 from readings [18, 12, 9, 12, 12]
# Found bad index 1 which is value 83 from readings [89, 83, 81, 78, 75, 76, 74, 70]
# Found bad index 1 which is value 41 from readings [46, 41, 39, 36, 37, 32]
# Found bad index 1 which is value 78 from readings [83, 78, 75, 74, 71, 71, 69, 67]
# Found bad index 1 which is value 40 from readings [47, 40, 40, 39, 38, 35, 32, 35]
# Found bad index 1 which is value 41 from readings [46, 41, 39, 37, 37, 37]
# Found bad index 1 which is value 51 from readings [58, 51, 48, 48, 47, 45, 41]
# Found bad index 1 which is value 60 from readings [65, 60, 60, 59, 53]
# Found bad index 1 which is value 19 from readings [26, 19, 15, 13, 12]
# Found bad index 1 which is value 11 from readings [17, 11, 9, 8, 4, 5]
# Found bad index 1 which is value 83 from readings [89, 83, 82, 80, 76, 75, 73, 73]
# Found bad index 1 which is value 66 from readings [71, 66, 63, 62, 59, 55, 51]
# Found bad index 1 which is value 73 from readings [78, 73, 69, 67, 60]
# Found bad index 1 which is value 32 from readings [39, 32, 26, 24, 23, 22, 19]
# Found bad index 1 which is value 64 from readings [70, 64, 59, 57, 54, 51, 50, 51]
# Found bad index 1 which is value 23 from readings [30, 23, 18, 15, 15]
# Found bad index 1 which is value 72 from readings [79, 72, 69, 64, 60]
# Found bad index 1 which is value 19 from readings [25, 19, 16, 11, 8, 2]
# Found bad index 1 which is value 44 from readings [48, 44, 42, 39, 39]
# Found bad index 1 which is value 8 from readings [4, 8, 14, 17, 17]
# Found bad index 5 which is value 86 from readings [92, 91, 90, 89, 86, 86]
# Found bad index 2 which is value 15 from readings [16, 19, 15, 13, 12, 6]
# Found bad index 2 which is value 29 from readings [39, 36, 29, 28, 31]
# Found bad index 2 which is value 77 from readings [78, 75, 77, 78, 79, 79]
# Found bad index 1 which is value 24 from readings [20, 24, 26, 29, 33, 37]
# Found bad index 2 which is value 82 from readings [81, 78, 82, 85, 86]
# Found bad index 1 which is value 37 from readings [41, 37, 30, 29, 28, 26, 24, 24]
# Found bad index 1 which is value 73 from readings [68, 73, 80, 82, 81]
# OG SAFE!  246
# 294
